# %%
import pandas as pd
import numpy as np
import lasio

las = lasio.read(r'../../data_well_log/las_files_Lithostrat_data/7_1-1.las')
df = las.df()
df.head()
# Out:
#          FORCE_2020_LITHOFACIES_CONFIDENCE  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# DEPT
# 82.6008                                NaN                               NaN
# 82.7528                                NaN                               NaN
# 82.9048                                NaN                               NaN
# 83.0568                                NaN                               NaN
# 83.2088                                NaN                               NaN
#
#          CALI    BS  DCAL  MUDWEIGHT  ROP  RDEP  RSHA  RMED  SP  DTC  NPHI  \
# DEPT
# 82.6008   NaN  36.0   NaN        NaN  NaN   NaN   NaN   NaN NaN  NaN   NaN
# 82.7528   NaN  36.0   NaN        NaN  NaN   NaN   NaN   NaN NaN  NaN   NaN
# 82.9048   NaN  36.0   NaN        NaN  NaN   NaN   NaN   NaN NaN  NaN   NaN
# 83.0568   NaN  36.0   NaN        NaN  NaN   NaN   NaN   NaN NaN  NaN   NaN
# 83.2088   NaN  36.0   NaN        NaN  NaN   NaN   NaN   NaN NaN  NaN   NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 17982 entries, 82.600799561 to 2815.7127996
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   FORCE_2020_LITHOFACIES_CONFIDENCE  16241 non-null  float64
#  1   FORCE_2020_LITHOFACIES_LITHOLOGY   16242 non-null  float64
#  2   CALI                               16270 non-null  float64
#  3   BS                                 17947 non-null  float64
#  4   DCAL                               16272 non-null  float64
#  5   MUDWEIGHT                          15724 non-null  float64
#  6   ROP                                17343 non-null  float64
#  7   RDEP                               16121 non-null  float64
#  8   RSHA                               16115 non-null  float64
#  9   RMED                               16152 non-null  float64
#  10  SP                                 16151 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# FORCE_2020_LITHOFACIES_CONFIDENCE     1741
# FORCE_2020_LITHOFACIES_LITHOLOGY      1740
# CALI                                  1712
# BS                                      35
# DCAL                                  1710
# MUDWEIGHT                             2258
# ROP                                    639
# RDEP                                  1861
# RSHA                                  1867
# RMED                                  1830
# SP                                    1831
# DTC                                   6586
# NPHI                                 13578
# GR                                    1740
# RHOB                                 13585
# DRHO                                 13539
# DEPTH_MD                              1861
# X_LOC                                 1861
# Y_LOC                                 1861
# Z_LOC                                 1861
# dtype: int64

# %%
df.columns
# Out:
# Index(['FORCE_2020_LITHOFACIES_CONFIDENCE', 'FORCE_2020_LITHOFACIES_LITHOLOGY',
#        'CALI', 'BS', 'DCAL', 'MUDWEIGHT', 'ROP', 'RDEP', 'RSHA', 'RMED', 'SP',
#        'DTC', 'NPHI', 'GR', 'RHOB', 'DRHO', 'DEPTH_MD', 'X_LOC', 'Y_LOC',
#        'Z_LOC'],
#       dtype='object')

# %%
df.shape
# Out:
# (17982, 20)

# %%
X = df[['DEPTH_MD', 'CALI', 'RSHA', 'RMED', 'RDEP', 'RHOB', 'GR', 'NPHI', 'DTC', 'SP', 'BS']]

# %%
train = pd.read_csv('../../data_well_log/train.csv', sep=';')

# %%
train.head()
# Out:
#       WELL  DEPTH_MD         X_LOC      Y_LOC       Z_LOC         GROUP  \
# 0  15/9-13   494.528  437641.96875  6470972.5 -469.501831  NORDLAND GP.
# 1  15/9-13   494.680  437641.96875  6470972.5 -469.653809  NORDLAND GP.
# 2  15/9-13   494.832  437641.96875  6470972.5 -469.805786  NORDLAND GP.
# 3  15/9-13   494.984  437641.96875  6470972.5 -469.957794  NORDLAND GP.
# 4  15/9-13   495.136  437641.96875  6470972.5 -470.109772  NORDLAND GP.
#
#   FORMATION       CALI  RSHA      RMED  ...        ROP  DTS  DCAL      DRHO  \
# 0       NaN  19.480835   NaN  1.611410  ...  34.636410  NaN   NaN -0.574928
# 1       NaN  19.468800   NaN  1.618070  ...  34.636410  NaN   NaN -0.570188
# 2       NaN  19.468800   NaN  1.626459  ...  34.779556  NaN   NaN -0.574245
# 3       NaN  19.459282   NaN  1.621594  ...  39.965164  NaN   NaN -0.586315
# 4       NaN  19.453100   NaN  1.602679  ...  57.483765  NaN   NaN -0.597914
#
#    MUDWEIGHT  RMIC  ROPA  RXO  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# ...

# %%
well = train['WELL'].unique()
len(well)
# Out:
# 98

# %%
df_train = pd.read_csv('/media/Data-B/my_research/Geoscience_FL/data_well_log/train.csv', delimiter=';')
df_train.columns
# Out:
# Index(['WELL', 'DEPTH_MD', 'X_LOC', 'Y_LOC', 'Z_LOC', 'GROUP', 'FORMATION',
#        'CALI', 'RSHA', 'RMED', 'RDEP', 'RHOB', 'GR', 'SGR', 'NPHI', 'PEF',
#        'DTC', 'SP', 'BS', 'ROP', 'DTS', 'DCAL', 'DRHO', 'MUDWEIGHT', 'RMIC',
#        'ROPA', 'RXO', 'FORCE_2020_LITHOFACIES_LITHOLOGY',
#        'FORCE_2020_LITHOFACIES_CONFIDENCE'],
#       dtype='object')

# %% [markdown]
# **Some wells do not have the same curve data**

# %%
# Filter rows with WELL name as '35/4-1'
well_35_4_1 = df_train[df_train['WELL'] == '35/4-1']
well_35_4_1.columns
# Out:
# Index(['WELL', 'DEPTH_MD', 'X_LOC', 'Y_LOC', 'Z_LOC', 'GROUP', 'FORMATION',
#        'CALI', 'RSHA', 'RMED', 'RDEP', 'RHOB', 'GR', 'SGR', 'NPHI', 'PEF',
#        'DTC', 'SP', 'BS', 'ROP', 'DTS', 'DCAL', 'DRHO', 'MUDWEIGHT', 'RMIC',
#        'ROPA', 'RXO', 'FORCE_2020_LITHOFACIES_LITHOLOGY',
#        'FORCE_2020_LITHOFACIES_CONFIDENCE'],
#       dtype='object')

# %%
log_curvers = ['CALI', 'BS', 'DCAL', 'ROP', 'RDEP', 'RSHA', 'RMED', 'SP', 'DTC', 'NPHI', 'GR', 'RHOB', 'DRHO']

well_35_4_1 = well_35_4_1[log_curvers]
well_35_4_1.head()
# Out:
#          CALI         BS  DCAL        ROP      RDEP  RSHA      RMED  SP  \
# 1076030   NaN  26.000002   NaN  14.999701  1.075178   NaN  1.005212 NaN
# 1076031   NaN  26.000002   NaN  14.999701  1.126755   NaN  1.105142 NaN
# 1076032   NaN  26.000002   NaN  14.999701  1.117510   NaN  1.139547 NaN
# 1076033   NaN  26.000002   NaN  14.999701  1.135859   NaN  1.207895 NaN
# 1076034   NaN  26.000002   NaN  15.135280  1.136199   NaN  1.202395 NaN
#
#                 DTC      NPHI         GR  RHOB  DRHO
# 1076030  144.359283  0.567329  46.560646   NaN   NaN
# 1076031  140.593689  0.560920  45.407211   NaN   NaN
# 1076032  140.705338  0.532830  44.425045   NaN   NaN
# 1076033  142.390594  0.520973  44.018967   NaN   NaN
# 1076034  145.113831  0.529003  43.864357   NaN   NaN
